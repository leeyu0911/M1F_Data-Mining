# %%
print(type(b))
# Out:
# <class 'tuple'>

# %%
z = {}
for i in range(2):
    temp = {**b[2*i], **b[2*i - 1]}
    z = {**z, **temp}

# %%
for i in z:
    if type(i) == str:
        z[tuple((i, ))] = z[i]
        del z[i]

# %%
len(z)
# Out:
# 242

# %%
len(a), len(z)
# Out:
# (239, 242)

# %%
aa = list(a.items())
bb = list(z.items())

# %%
aa = [[sorted(list(i[0])), i[1]] for i in a.items()]
bb = [[sorted(list(i[0])), i[1]] for i in z.items()]

# %%
for i in aa:
    if i in bb:
        pass
    else:
        print(i)
# 我沒有
# Out:
# [['517'], 18]
# [['129'], 18]
# [['520'], 18]
# [['830'], 19]
# [['248'], 19]
# [['962'], 19]
# [['214'], 19]
# [['436'], 19]
# [['155'], 19]
# [['241'], 19]
# [['859'], 19]
# [['327'], 19]
# [['998'], 20]
# [['89'], 20]
# [['557'], 20]
# [['80'], 20]
# [['336'], 20]
# [['93'], 21]
# [['699'], 21]
# [['335'], 21]
# [['717'], 21]
# [['799'], 21]
# [['747'], 21]
# [['924'], 21]
# [['395'], 21]
# [['970'], 21]
# [['277'], 21]
# [['429'], 21]
# [['877'], 21]
# [['146'], 21]
# [['144'], 22]
# [['545'], 22]
# [['83'], 22]
# [['168'], 23]
# [['601'], 23]
# [['463'], 23]
# [['231'], 23]
# [['159'], 23]
# [['453'], 23]
# [['510'], 23]
# [['403'], 24]
# [['732'], 24]
# [['555'], 25]
# [['182'], 25]
# [['14'], 25]
# [['39'], 25]
# [['803'], 26]
# [['201'], 26]
# [['613'], 26]
# [['619'], 26]
# [['124'], 26]
# [['119'], 27]
# [['558'], 28]
# [['662'], 28]
# [['51'], 28]
# [['833'], 28]
# [['604'], 28]
# [['150'], 28]
# [['946'], 28]
# [['879'], 29]
# [['915'], 29]
# [['17'], 29]
# [['820'], 29]
# ...

# %%
for i in bb:
    if i in aa:
        pass
    else:
        print(i)
# Out:
# [['1', '5', '7'], 18]
# [['5', '5', '5'], 25]
# [['0', '6', '8'], 33]
# [['7', '8', '9'], 29]
# [['1', '5', '9'], 29]
# [['3', '8'], 46]
# [['3', '9'], 21]
# [['1', '6', '8'], 23]
# [['1', '3', '3'], 32]
# [['2', '5', '9'], 36]
# [['5', '9', '9'], 36]
# [['1', '4', '4'], 22]
# [['1', '3', '8'], 51]
# [['5', '5', '9'], 35]
# [['0', '3', '8'], 19]
# [['6', '9', '9'], 21]
# [['1', '7'], 29]
# [['1', '2', '9'], 18]
# [['2', '2', '7'], 40]
# [['8', '9', '9'], 20]
# [['1', '3', '6'], 33]
# [['0', '1', '6'], 23]
# [['1', '6', '9'], 47]
# [['3', '3', '5'], 21]
# [['7', '8'], 52]
# [['8', '9'], 20]
# [['2', '4', '8'], 19]
# [['0', '3', '4'], 24]
# [['3', '4', '6'], 23]
# [['0', '2', '8'], 29]
# [['2', '7', '9'], 32]
# [['3', '6'], 66]
# [['1', '7', '7'], 21]
# [['0', '3', '8'], 26]
# [['3', '4', '4'], 39]
# [['4', '6', '7'], 53]
# [['3', '6', '8'], 40]
# [['2', '6'], 32]
# [['1', '7'], 40]
# [['0', '2', '4'], 30]
# [['7', '9', '9'], 21]
# [['5', '5', '8'], 28]
# [['3', '6', '8'], 37]
# ...

# %%
filename = '/Users/leeyu/OneDrive/GitHub/M1F_Data-Mining/Homework_1/dataset/test_data.csv'
        
with open(filename) as f:
    content = f.readlines()
content = [s.strip() for s in content]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-4a2bb9979046> in <module>
#       1 filename = '/Users/leeyu/OneDrive/GitHub/M1F_Data-Mining/Homework_1/dataset/test_data.csv'
#       2
# ----> 3 with open(filename) as f:
#       4     content = f.readlines()
#       5 content = [s.strip() for s in content]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/leeyu/OneDrive/GitHub/M1F_Data-Mining/Homework_1/dataset/test_data.csv'

# %%
transactions = []
for c in content[1:]:
    temp = c.replace(',', ' ').split(' ')[1:]
    transactions.append(temp)

# %%
set(['118', '364']).issubset(set(['118', '266', '364', '427', '628', '673', '868', '904']))

# %%
t=[[['132', '493', '626'], 19],
[['187', '656'], 18] ,
[['187', '493'], 18] ,
[['132', '187'], 18] ,
[['187', '626', '656'], 18],
[['132', '187', '626'], 18],
[['187', '493', '656'], 18] ,
[['132', '187', '493'], 18]  ,
[['187', '493', '626', '656'], 18],
[['132', '187', '626', '656'], 18],
[['132', '187', '493', '626'], 18],
[['132', '187', '493', '626', '656'], 18],
[['493', '650'], 18] ,
[['187', '493', '650'], 18] ,
[['132', '650', '656'], 18],
[['132', '187', '650', '656'], 18],
[['132', '493', '650', '656'], 18],
[['132', '187', '493', '650', '656'], 18]]


l = []
for tt in t:
    c = 0
    for i in transactions:
        if set(tt[0]).issubset(i):
            c += 1
    l.append(c)
l

# %%
froz = {'118': 34, '427': 21, '628': 43, '673': 25, '868': 29, '40': 27, '316': 27, '594': 19, '870': 34, '132': 64, '209': 23, '314': 25, '439': 34, '553': 80, '592': 58, '885': 26, '128': 22, '188': 25, '319': 21, '374': 53, '432': 54, '456': 33, '511': 32, '707': 19, '767': 18, '894': 38, '63': 53, '142': 19, '493': 45, '761': 34, '908': 27, '148': 25, '571': 42, '607': 75, '634': 30, '674': 26, '790': 23, '974': 23, '409': 19, '464': 22, '753': 28, '829': 44, '442': 66, '721': 23, '988': 55, '187': 22, '480': 29, '626': 29, '650': 19, '656': 39, '238': 73, '471': 66, '490': 18, '738': 27, '837': 38, '914': 22, '973': 63, '992': 41, '994': 49, '996': 35, '623': 20, '652': 18, '444': 62, '550': 28, '667': 27, '808': 36, '902': 50, '137': 22, '170': 19, '215': 27, '273': 19, '565': 19, '909': 42, '913': 30, '8': 46, '293': 55, '521': 18, '549': 36, '800': 42, '883': 30, '989': 27, '116': 24, '371': 18, '85': 31, '117': 40, '259': 40, '291': 20, '360': 27, '486': 35, '575': 20, '744': 25, '778': 29, '832': 26, '246': 18, '559': 42, '180': 21, '306': 22, '561': 25, '28': 36, '154': 42, '517': 18, '555': 25, '806': 33, '879': 29, '915': 29, '38': 46, '93': 21, '168': 23, '331': 32, '925': 36, '959': 36, '144': 22, '318': 51, '595': 35, '830': 19, '699': 21, '17': 29, '129': 18, '722': 40, '998': 20, '163': 33, '601': 23, '961': 47, '335': 21, '87': 52, '89': 20, '248': 19, '403': 24, '463': 23, '820': 29, '729': 32, '36': 66, '717': 21, '803': 26, '344': 39, '647': 53, '863': 40, '62': 32, '71': 40, '402': 30, '799': 21, '558': 28, '638': 37, '676': 32, '747': 21, '405': 63, '445': 30, '962': 19, '214': 19, '631': 35, '662': 28, '737': 30, '119': 27, '182': 25, '127': 31, '709': 38, '472': 44, '827': 49, '231': 23, '14': 25, '201': 26, '524': 31, '557': 20, '212': 32, '51': 28, '69': 43, '613': 26, '833': 28, '3': 41, '545': 22, '80': 20, '436': 19, '520': 18, '732': 24, '924': 21, '39': 25, '159': 23, '604': 28, '368': 34, '395': 21, '970': 21, '619': 26, '150': 28, '155': 19, '241': 19, '946': 28, '336': 20, '807': 41, '221': 43, '859': 19, '83': 22, '453': 23, '277': 21, '327': 19, '429': 21, '510': 23, '877': 21, '124': 26, '146': 21, '289': 18, '222': 37, '229': 19, '903': 19, '938': 19, '19': 27, '764': 25, '34': 18, '874': 20, '66': 22, '497': 18, '831': 18}, {('34', '87'): 18, ('626', '132'): 19, ('118', '427'): 19, ('405', '557'): 19, ('607', '471'): 30, ('650', '187'): 19, ('656', '132'): 18, ('656', '493'): 19, ('187', '132'): 19, ('132', '493'): 21, ('187', '626'): 18, ('187', '656'): 21, ('650', '132'): 18, ('626', '493'): 20, ('650', '656'): 18, ('650', '493'): 19, ('187', '493'): 20}, {('187', '650', '493'): 19, ('187', '656', '493'): 19, ('656', '132', '493'): 18, ('187', '493', '626'): 18, ('187', '132', '650'): 18, ('187', '656', '132'): 18, ('187', '656', '650'): 18, ('132', '650', '493'): 18, ('656', '650', '493'): 18, ('132', '493', '626'): 18, ('187', '132', '493'): 19}, {('187', '656', '132', '493'): 18, ('187', '656', '650', '493'): 18, ('187', '650', '132', '493'): 18}

# %%
len(froz)

# %%
f = {}
for i in range(2):
    temp = {**b[2*i], **b[2*i - 1]}
    f = {**f, **temp}

# %%
f

# %%
cc = [[sorted(list(i[0])), i[1]] for i in f.items()]

for i in bb:
    if i in cc:
        pass
    else:
        print(i)
